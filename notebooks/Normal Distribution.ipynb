# %%
import numpy as np
from scipy.stats import *
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
mean, var, skew, kurt = norm.stats(moments='mvsk')
print(mean)
print(var)
# Out:
# 0.0
# 1.0

# %%
x = np.linspace(norm.ppf(0.01),norm.ppf(0.99), 100)
plt.plot(x, norm.pdf(x),'r-', lw=5, alpha=0.6, label='norm pdf')

# %%
# Freeze the distribution and display the frozen pdf:
rv = norm()
plt.plot(x, rv.pdf(x), 'k-', lw=2, label='frozen pdf')

# %%
# Check accuracy of cdf and ppf:
vals = norm.ppf([0.001, 0.5, 0.999])
np.allclose([0.001, 0.5, 0.999], norm.cdf(vals))
# Out:
# True

# %%
# Generate random numbers
r = norm.rvs(size=1000)
# And compare the histogram
plt.hist(r, normed=True, histtype='stepfilled', alpha=0.2)
# Out:
# (array([   2.,   16.,   76.,  162.,  271.,  261.,  156.,   46.,    8.,    2.]),
#  array([-3.42633436, -2.70565908, -1.9849838 , -1.26430853, -0.54363325,
#          0.17704203,  0.89771731,  1.61839259,  2.33906787,  3.05974314,
#          3.78041842]),
#  <a list of 10 Patch objects>)
